# %% [markdown]
# Mars crateres
# First I stablished two variables Depth and diagram of the Circle crateres.
# the first thing I try is claryfied the data of diam circle image between the values 50, 85 km. Then counts the number of repetitions, Percentages. Same for depth. Then try a simple correlation by matrix.
# becouse the data of mars craters is so long I use only 5000 data sets, I am trying first corroborate the posible outcomes. My initial research question was the many of this call craters were not. Many of them are just topologycal natural statments.

# %%
import pandas
import numpy


data = pandas.read_csv("crateres.csv")

sub1 = data[(data["DIAM_CIRCLE_IMAGE"]>=50) & (data["DIAM_CIRCLE_IMAGE"]<=85)]
sub2 = sub1.copy()

print ("counts for original DIAM_CIRCLE_IMAGE")

c1 = sub2["DIAM_CIRCLE_IMAGE"].value_counts(sort=False, dropna=False)
print(c1)

diameter = data['DIAM_CIRCLE_IMAGE'].value_counts(sort = False, dropna = False)
print ("Counts for DIAM_CIRCLE_IMAGE - Crater diameter in km")
print (diameter.sort_index())


diameter_percent = data['DIAM_CIRCLE_IMAGE'].value_counts(sort = False, dropna = False, normalize = True)
print ("Percentages for DIAM_CIRCLE_IMAGE")
print (diameter_percent.sort_index())


depth = data["DEPTH_RIMFLOOR_TOPOG"].value_counts(sort=False, dropna=False)
print ("counts for DEPTH_RIMFLOOR_TOPOG")
print (depth.sort_index())


depth_percent = data["DEPTH_RIMFLOOR_TOPOG"].value_counts(sort=False, dropna=False)
print ("percent for DEPTH_RIMFLOOR_TOPOG")
print (depth.sort_index())

print (pandas.crosstab(sub2["DIAM_CIRCLE_IMAGE"], sub2["DEPTH_RIMFLOOR_TOPOG"]))

sub3 = sub2[["DIAM_CIRCLE_IMAGE", "DEPTH_RIMFLOOR_TOPOG"]]
sub3.head (25)

data["NUMETHNIC"] = data["DIAM_CIRCLE_IMAGE"] + data["DEPTH_RIMFLOOR_TOPOG"]
chk8 = data["NUMETHNIC"].value_counts(sort=False, dropna=False)
print ("counts for NUMETHNIC value")
print (chk8)
# Out:
# counts for original DIAM_CIRCLE_IMAGE
# 55.24    1
# 74.81    1
# 73.53    1
# 70.11    1
# 52.37    1
# 58.40    1
# 63.57    1
# 72.66    1
# 51.31    1
# 51.08    1
# 79.63    1
# 82.02    1
# 82.10    1
# Name: DIAM_CIRCLE_IMAGE, dtype: int64
# Counts for DIAM_CIRCLE_IMAGE - Crater diameter in km
# 1.21     48
# 1.22     47
# 1.23     64
# 1.24     37
# 1.25     56
# 1.26     41
# 1.27     48
# 1.28     41
# 1.29     50
# 1.30     39
# 1.31     51
# 1.32     46
# 1.33     53
# 1.34     57
# 1.35     36
# 1.36     44
# 1.37     44
# 1.38     50
# 1.39     45
# 1.40     42
# 1.41     31
# 1.42     38
# 1.43     36
# 1.44     40
# 1.45     30
# 1.46     39
# 1.47     38
# 1.48     33
# 1.49     43
# 1.50     20
#          ..
# 35.82     1
# 36.28     1
# 36.41     1
# 36.85     1
# 39.51     1
# 40.90     1
# 43.03     1
# 43.57     1
# 43.75     1
# 45.71     1
# 45.85     1
# 46.03     1
# 47.20     1
# 48.44     1
# 48.84     1
# 49.43     1
# 49.78     1
# 51.08     1
# 51.31     1
# 52.37     1
# 55.24     1
# 58.40     1
# 63.57     1
# 70.11     1
# 72.66     1
# 73.53     1
# 74.81     1
# 79.63     1
# 82.02     1
# 82.10     1
# Name: DIAM_CIRCLE_IMAGE, dtype: int64
# Percentages for DIAM_CIRCLE_IMAGE
# 1.21     0.009602
# 1.22     0.009402
# 1.23     0.012803
# 1.24     0.007401
# 1.25     0.011202
# 1.26     0.008202
# 1.27     0.009602
# 1.28     0.008202
# 1.29     0.010002
# 1.30     0.007802
# 1.31     0.010202
# 1.32     0.009202
# 1.33     0.010602
# 1.34     0.011402
# 1.35     0.007201
# 1.36     0.008802
# 1.37     0.008802
# 1.38     0.010002
# 1.39     0.009002
# 1.40     0.008402
# 1.41     0.006201
# 1.42     0.007602
# 1.43     0.007201
# 1.44     0.008002
# 1.45     0.006001
# 1.46     0.007802
# 1.47     0.007602
# 1.48     0.006601
# 1.49     0.008602
# 1.50     0.004001
#            ...
# 35.82    0.000200
# 36.28    0.000200
# 36.41    0.000200
# 36.85    0.000200
# 39.51    0.000200
# 40.90    0.000200
# 43.03    0.000200
# 43.57    0.000200
# 43.75    0.000200
# 45.71    0.000200
# 45.85    0.000200
# 46.03    0.000200
# 47.20    0.000200
# 48.44    0.000200
# 48.84    0.000200
# 49.43    0.000200
# 49.78    0.000200
# 51.08    0.000200
# 51.31    0.000200
# 52.37    0.000200
# 55.24    0.000200
# 58.40    0.000200
# 63.57    0.000200
# 70.11    0.000200
# 72.66    0.000200
# 73.53    0.000200
# 74.81    0.000200
# 79.63    0.000200
# 82.02    0.000200
# 82.10    0.000200
# Name: DIAM_CIRCLE_IMAGE, dtype: float64
# counts for DEPTH_RIMFLOOR_TOPOG
# -0.01       1
#  0.00    3773
#  0.01     177
#  0.02     206
#  0.03     151
#  0.04      98
#  0.05      78
#  0.06      46
#  0.07      55
#  0.08      41
#  0.09      27
#  0.10      25
#  0.11      35
#  0.12      21
#  0.13      14
#  0.14      12
#  0.15      22
#  0.16      19
#  0.17       6
#  0.18       7
#  0.19      10
#  0.20       5
#  0.21       8
#  0.22       7
#  0.23       9
#  0.24       3
#  0.25       5
#  0.26       4
#  0.27       2
#  0.28       3
#          ...
#  0.87       1
#  0.88       2
#  0.92       1
#  0.94       2
#  0.95       1
#  0.96       1
#  0.98       1
#  0.99       1
#  1.01       1
#  1.03       1
#  1.05       2
#  1.06       1
#  1.10       1
#  1.11       1
#  1.12       1
#  1.14       1
#  1.20       1
#  1.21       1
#  1.26       1
#  1.32       1
#  1.35       1
#  1.41       2
#  1.74       1
#  1.77       1
#  1.85       1
#  1.86       1
#  1.90       1
#  1.97       1
#  1.98       1
#  2.08       1
# Name: DEPTH_RIMFLOOR_TOPOG, dtype: int64
# percent for DEPTH_RIMFLOOR_TOPOG
# -0.01       1
#  0.00    3773
#  0.01     177
#  0.02     206
#  0.03     151
#  0.04      98
#  0.05      78
#  0.06      46
#  0.07      55
#  0.08      41
#  0.09      27
#  0.10      25
#  0.11      35
#  0.12      21
#  0.13      14
#  0.14      12
#  0.15      22
#  0.16      19
#  0.17       6
#  0.18       7
#  0.19      10
#  0.20       5
#  0.21       8
#  0.22       7
#  0.23       9
#  0.24       3
#  0.25       5
#  0.26       4
#  0.27       2
#  0.28       3
#          ...
#  0.87       1
#  0.88       2
#  0.92       1
#  0.94       2
#  0.95       1
#  0.96       1
#  0.98       1
#  0.99       1
#  1.01       1
#  1.03       1
#  1.05       2
#  1.06       1
#  1.10       1
#  1.11       1
#  1.12       1
#  1.14       1
#  1.20       1
#  1.21       1
#  1.26       1
#  1.32       1
#  1.35       1
#  1.41       2
#  1.74       1
#  1.77       1
#  1.85       1
#  1.86       1
#  1.90       1
#  1.97       1
#  1.98       1
#  2.08       1
# Name: DEPTH_RIMFLOOR_TOPOG, dtype: int64
# DEPTH_RIMFLOOR_TOPOG  0.00  0.05  0.07  0.09  0.10  0.11  0.13  0.19  0.22  \
# DIAM_CIRCLE_IMAGE
# 51.08                    0     0     0     0     0     0     0     0     0
# 51.31                    0     0     0     0     0     0     1     0     0
# 52.37                    0     0     1     0     0     0     0     0     0
# 55.24                    1     0     0     0     0     0     0     0     0
# 58.40                    0     0     0     0     0     1     0     0     0
# 63.57                    0     1     0     0     0     0     0     0     0
# 70.11                    0     0     0     0     1     0     0     0     0
# 72.66                    0     0     0     0     0     0     0     1     0
# 73.53                    0     0     0     0     0     1     0     0     0
# 74.81                    0     0     0     0     0     0     1     0     0
# 79.63                    0     0     0     1     0     0     0     0     0
# 82.02                    0     0     0     0     0     0     0     0     0
# 82.10                    0     0     0     0     0     0     0     0     1
#
# DEPTH_RIMFLOOR_TOPOG  1.74  1.97
# DIAM_CIRCLE_IMAGE
# 51.08                    1     0
# 51.31                    0     0
# 52.37                    0     0
# 55.24                    0     0
# 58.40                    0     0
# 63.57                    0     0
# 70.11                    0     0
# 72.66                    0     0
# 73.53                    0     0
# 74.81                    0     0
# 79.63                    0     0
# 82.02                    0     1
# 82.10                    0     0
# counts for NUMETHNIC value
# 1.75     26
# 2.75      4
# 3.75      5
# 4.75      2
# 5.75      2
# 6.50      2
# 7.50      2
# 8.75      2
# 9.00      1
# 10.00     1
# 12.75     1
# 2.13     20
# 2.50      7
# 20.25     1
# 23.25     1
# 27.75     1
# 3.50      2
# 4.01      3
# 3.13      9
# 34.75     1
# 2.25      9
# 4.50      4
# 5.50      1
# 4.13      2
# 3.25      9
# 6.00      1
# 7.00      1
# 4.88      1
# 4.25      2
# 8.50      2
#          ..
# 9.84      2
# 12.09     1
# 13.59     1
# 17.84     1
# 21.59     1
# 26.34     1
# 28.09     1
# 30.34     1
# 31.59     1
# 4.64      3
# 41.59     1
# 2.58     12
# 9.39      1
# 10.39     1
# 2.43     10
# 1.58     38
# 9.07      1
# 4.49      1
# 9.82      1
# 1.64     23
# 4.33      1
# 4.32      1
# 5.33      2
# 7.07      1
# 17.90     1
# 5.07      1
# 6.07      1
# 3.29      7
# 2.54     11
# 4.54      3
# Name: NUMETHNIC, dtype: int64
